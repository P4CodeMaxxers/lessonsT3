# %% [raw]
# ---
# layout: post
# title: Void Striker — Shoot to Unlock the Backgrounds Lesson
# description: Destroy enemies to unlock each concept in the Backgrounds lesson — parallax layers, animated depth, and runtime scene swapping.
# permalink: /backgrounds
# codemirror: true
# hide: true
# toc: false
# ---

# %% [markdown]
# ## Void Striker
#
# Destroy enemies to unlock each section of the **Backgrounds** lesson.
# Every visual trick in this game — the drifting nebula, the twinkling stars, the glowing dust — is a technique you will learn by playing through it.
#
# **Shoot 5 enemies** to unlock the next lesson block. Keep going until all 3 sections are revealed.
#
# ### Controls
#
# | Key | Action |
# |---|---|
# | Arrow keys / WASD | Move your ship |
# | Space | Fire (triple-shot spread) |
# | Background button (top center) | Cycle between Nebula, Deep Space, and Supernova scenes |

# %%
# %%js
#
# // GAME_RUNNER: Void Striker | hide_edit: true, width: 100%, height: 500px
#
# import GameControl from '/assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelVoidStriker from '/assets/js/projects/backgrounds/levels/GameLevelVoidStriker.js';
# export const gameLevelClasses = [GameLevelVoidStriker];
# export { GameControl };

# %% [markdown]
# <div id='lesson-progress-bar' style='
#   display: flex;
#   flex-direction: row;
#   gap: 8px;
#   align-items: center;
#   font-family: monospace;
#   background: #0a001a;
#   border: 1px solid #4400aa;
#   padding: 10px 14px;
#   border-radius: 6px;
#   margin-bottom: 10px;
#   flex-wrap: wrap;
# '>
#   <span style='color:#aaaaff; font-size:13px; margin-right:6px;'>Progress:</span>
#   <div id='sq-1' style='width:80px; height:36px; border:2px solid #4400aa; border-radius:5px; display:flex; align-items:center; justify-content:center; font-size:11px; color:#553388; background:#0d0020; text-align:center; padding:2px;'>🔒<br>Concept 1</div>
#   <div id='sq-2' style='width:80px; height:36px; border:2px solid #4400aa; border-radius:5px; display:flex; align-items:center; justify-content:center; font-size:11px; color:#553388; background:#0d0020; text-align:center; padding:2px;'>🔒<br>Hack 1</div>
#   <div id='sq-3' style='width:80px; height:36px; border:2px solid #4400aa; border-radius:5px; display:flex; align-items:center; justify-content:center; font-size:11px; color:#553388; background:#0d0020; text-align:center; padding:2px;'>🔒<br>Concept 2</div>
#   <span id='kill-counter' style='margin-left:auto; color:#aaaaff; font-size:12px; opacity:0.7;'>0 kills</span>
# </div>
# <div id='lesson-progress' style='font-family: monospace; background: #0a001a; border: 1px solid #4400aa; padding: 10px 18px; border-radius: 6px; color: #aaaaff; font-size: 13px; margin-bottom: 8px;'>
#   🔒 <strong>Lesson locked.</strong> Destroy 5 enemies in-game to reveal the first concept.
#   <br><span style='opacity:0.6; font-size:12px;'>Keep shooting — each 5 kills unlocks the next section.</span>
# </div>

# %% [raw]
# <div class='lesson-block' id='lesson-1' style='display:none'>
# <hr />
# <h2>🔒 Concept 1 — Parallax Backgrounds <em>(unlock: 5 kills)</em></h2>
# <p>A background is anything drawn <strong>before</strong> your game objects each frame. The canvas paints top-to-bottom, so whatever you draw first ends up underneath everything else. Register your background as the <strong>first entry</strong> in <code>this.classes</code>:</p>
# <pre><code class="language-javascript">this.classes = [
#   { class: GameEnvBackground, data: image_data_space }, // must be first
#   { class: GameLevelEnemy,    data: enemy_data },
#   { class: GameLevelPlayer,   data: player_data },
# ];
# </code></pre>
# <p><strong>Parallax</strong> is the illusion of depth created by moving layers at different speeds. Close things move fast, distant things move slow — your brain reads that difference as distance. No 3D math needed, just a <code>speed</code> value per layer:</p>
# <pre><code class="language-javascript">// Far away — moves slowly (feels distant)
# const farStars  = { speed: 0.1 };
#
# // Close — zooms past (feels near)
# const nearDust  = { speed: 2.5 };
# </code></pre>
# <p>Each frame, every particle moves down by its <code>speed</code> and wraps back to the top:</p>
# <pre><code class="language-javascript">// % H is modulo — when y reaches the canvas bottom (H), it resets to 0.
# // This creates an endless scroll with no if-statements.
# particle.y = (particle.y + particle.speed) % H;
# </code></pre>
# <p>Void Striker stacks five layers from slowest to fastest. Draw order matters — layer 1 is drawn first (farthest back), layer 5 last (closest):</p>
# <table>
# <thead><tr><th>Layer</th><th>What It Is</th><th>Speed</th></tr></thead>
# <tbody>
# <tr><td>1 — Deep Nebula</td><td>Pre-rendered canvas, seamless drift</td><td>0.04</td></tr>
# <tr><td>2 — Far Starfield</td><td>Tiny dim stars</td><td>0.08–0.18</td></tr>
# <tr><td>3 — Mid Starfield</td><td>Brighter stars with twinkle</td><td>0.25–0.5</td></tr>
# <tr><td>4 — Near Stars</td><td>Large stars with motion trails</td><td>0.8–1.6</td></tr>
# <tr><td>5 — Cosmic Dust</td><td>Glowing cyan particles</td><td>1.5–3.2</td></tr>
# </tbody>
# </table>
# <p><strong>The depth illusion lives entirely in the speed difference.</strong> Set every layer to the same speed and parallax vanishes — it all scrolls as a flat wall.</p>
# </div>

# %% [raw]
# <div class='lesson-block' id='lesson-2' style='display:none'>
# <hr />
# <h2>🔒 Hack 1 — Try It Yourself! Pre-Render Once, Copy Every Frame <em>(unlock: 10 kills)</em></h2>
#
# <h3>The Problem</h3>
# <p>The nebula background looks great, but it's expensive to draw. It's built from overlapping color gradients, and calculating each one touches thousands of pixels. At 60 frames per second, redrawing it from scratch every frame will tank your performance fast.</p>
#
# <h3>The Fix: Draw Once, Stamp Every Frame</h3>
# <p>Think of it like a rubber stamp. You carve the stamp once, then press it as many times as you want. Here, you paint the nebula onto a hidden off-screen canvas one time at startup. Every frame after that, you just copy that pre-drawn image onto the visible canvas using <code>drawImage</code>. Copying a finished image is way cheaper than recalculating gradients over and over.</p>
# <p>Here's the shape of the approach before you dive into code:</p>
# <ol>
# <li>Create a hidden canvas (the &quot;stamp&quot;)</li>
# <li>Paint the nebula onto it once</li>
# <li>Every frame, copy the stamp onto the screen and scroll it down slightly</li>
# <li>Draw it twice so there's never a gap as it scrolls</li>
# </ol>
#
# <h3>Step 1 — Create the off-screen canvas</h3>
# <p>This canvas is invisible to the player. It just lives in memory as your pre-drawn stamp. You only need to do this once when the game loads.</p>
# <pre><code class="language-javascript">// W and H are your game canvas width and height
# const bgCanvas = document.createElement('canvas');
# bgCanvas.width  = W;
# bgCanvas.height = H;
# const bgCtx = bgCanvas.getContext('2d'); // draw context for the hidden canvas
# </code></pre>
#
# <h3>Step 2 — Paint the nebula onto it (once)</h3>
# <p>This function runs exactly one time. It builds the dark space gradient as a base, then layers a glowing purple cloud on top using a radial gradient.</p>
# <pre><code class="language-javascript">function buildBackgroundScene() {
#   // Dark space gradient: top is near-black, middle is deep purple
#   const base = bgCtx.createLinearGradient(0, 0, 0, H);
#   base.addColorStop(0,   '#020010');
#   base.addColorStop(0.5, '#0a0025');
#   bgCtx.fillStyle = base;
#   bgCtx.fillRect(0, 0, W, H);
#
#   // Glowing nebula cloud: fades from purple at center to transparent at edge
#   const cloud = bgCtx.createRadialGradient(W*0.4, H*0.3, 0, W*0.4, H*0.3, W*0.5);
#   cloud.addColorStop(0, 'rgba(80, 0, 180, 0.4)');
#   cloud.addColorStop(1, 'transparent');
#   bgCtx.fillStyle = cloud;
#   bgCtx.fillRect(0, 0, W, H);
# }
#
# buildBackgroundScene(); // called ONCE, stamp is ready
# </code></pre>
#
# <h3>Step 3 — Copy and scroll it every frame</h3>
# <p><code>offsetY</code> starts at 0 and ticks up by 0.04 each frame, making the image slowly drift downward. The <code>% H</code> wraps it back to 0 when it hits the bottom, creating an endless loop with no extra if-statements.</p>
# <pre><code class="language-javascript">const layerNebula = { offsetY: 0 };
#
# function drawNebula() {
#   layerNebula.offsetY = (layerNebula.offsetY + 0.04) % H;
#
#   // Draw the stamp twice, stacked vertically, so there's never a gap
#   ctx.drawImage(bgCanvas, 0, layerNebula.offsetY - H); // slides in from above
#   ctx.drawImage(bgCanvas, 0, layerNebula.offsetY);     // main copy drifting down
# }
# </code></pre>
# <p>Why two copies? As the bottom image drifts off the bottom of the screen, the top copy slides in from above to fill the gap. When <code>offsetY</code> wraps back to 0, the loop starts over, completely seamless.</p>
#
# <h3>Putting it all together</h3>
# <p>Here's the full pattern from start to finish, the way you'd wire it up in your own game:</p>
# <pre><code class="language-javascript">// 1. Create the hidden canvas
# const bgCanvas = document.createElement('canvas');
# bgCanvas.width = W; bgCanvas.height = H;
# const bgCtx = bgCanvas.getContext('2d');
#
# // 2. Paint once at startup
# function buildBackgroundScene() {
#   const base = bgCtx.createLinearGradient(0, 0, 0, H);
#   base.addColorStop(0,   '#020010');
#   base.addColorStop(0.5, '#0a0025');
#   bgCtx.fillStyle = base;
#   bgCtx.fillRect(0, 0, W, H);
#
#   const cloud = bgCtx.createRadialGradient(W*0.4, H*0.3, 0, W*0.4, H*0.3, W*0.5);
#   cloud.addColorStop(0, 'rgba(80, 0, 180, 0.4)');
#   cloud.addColorStop(1, 'transparent');
#   bgCtx.fillStyle = cloud;
#   bgCtx.fillRect(0, 0, W, H);
# }
# buildBackgroundScene();
#
# // 3. Scroll and copy every frame (call this at the start of your game loop)
# const layerNebula = { offsetY: 0 };
# function drawNebula() {
#   layerNebula.offsetY = (layerNebula.offsetY + 0.04) % H;
#   ctx.drawImage(bgCanvas, 0, layerNebula.offsetY - H);
#   ctx.drawImage(bgCanvas, 0, layerNebula.offsetY);
# }
#
# // 4. To swap scenes at runtime, just call buildBackgroundScene() again
# //    with different colors. The next frame picks it up automatically.
# </code></pre>
# <p><strong>Bonus:</strong> This same pattern works for any visual swap at runtime, like day to night, calm to storm, or switching level themes. Just repaint <code>bgCanvas</code> with new colors when you need a change, and every future frame will automatically use the updated image.</p>
# <p style='margin-top:24px; padding:12px 16px; background:#0d2b00; border:1px solid #00cc44; border-radius:6px; color:#44ff88; font-family:monospace; font-size:13px;'>
# 🎉 <strong>Nice work!</strong> You just finished the main part of this lesson. Now try it in your own game — pick any background in your project and swap it out using the pre-render pattern you just learned.</p>
# </div>

# %% [raw]
# <div class='lesson-block' id='lesson-3' style='display:none'>
# <hr />
# <h2>🔒 Concept 2 — How the Shoot-to-Unlock System Works <em>(Extra Learning!)</em></h2>
# <p>The lesson blocks you just unlocked were hidden in the page from the start. Each one is a plain HTML <code>div</code> set to <code>display:none</code>. The game fires a custom browser event every time you hit a kill milestone, and a listener in the page hears it and reveals the next block.</p>
# <p><strong>Step 1 — The game fires an event at each milestone:</strong></p>
# <pre><code class="language-javascript">// Inside the game engine, after a kill is confirmed:
# this.killCount++;
# window.dispatchEvent(new CustomEvent('vs-kills', {
#   detail: { total: this.killCount }
# }));
# </code></pre>
# <p><strong>Step 2 — The page listens and unlocks blocks:</strong></p>
# <pre><code class="language-javascript">const milestones = [5, 10, 15]; // kills needed per block
# let unlocked = 0;
#
# window.addEventListener('vs-kills', function(e) {
#   const total = e.detail && e.detail.total;
#   if (!total) return;
#
#   milestones.forEach(function(m, idx) {
#     if (total >= m && unlocked <= idx) {
#       unlocked = idx + 1;
#       // Show the next lesson block
#       const block = document.getElementById('lesson-' + (idx + 1));
#       if (block) {
#         block.style.display = 'block';
#         block.style.animation = 'fadeIn 0.6s ease';
#       }
#     }
#   });
# });
# </code></pre>
# <p><strong>Why <code>CustomEvent</code>?</strong> It keeps the game and the lesson page completely separate. The game does not know anything about lesson blocks or HTML — it just announces a kill count. The page does not know anything about game internals — it just listens for a number. You could swap out the entire game engine and the unlock system would still work as long as the event name and payload stay the same.</p>
# <p>To add more blocks, add more milestones to the array and more <code>div</code>s with matching <code>id</code>s. The listener handles the rest automatically.</p>
# </div>

# %% [raw]
# <link rel='stylesheet' href='https://cdnjs.cloudflare.com/ajax/libs/highlight.js/11.9.0/styles/tokyo-night-dark.min.css'>
# <script src='https://cdnjs.cloudflare.com/ajax/libs/highlight.js/11.9.0/highlight.min.js'></script>
# <script>
# // Initialize highlight.js - will also be called after each unlock
# document.addEventListener('DOMContentLoaded', function() {
#   if (typeof hljs !== 'undefined') hljs.highlightAll();
# });
# </script>

# %% [markdown]
# <script>
# (function() {
#   const milestones = [5, 10, 15];
#   let unlocked = 0;
#
#   function updateSquare(n, label) {
#     var sq = document.getElementById('sq-' + n);
#     if (sq) {
#       sq.style.background = '#0d2b00';
#       sq.style.borderColor = '#00cc44';
#       sq.style.color = '#44ff88';
#       sq.innerHTML = '&#x2705;<br>' + label;
#     }
#   }
#
#   const labels = ['Concept 1', 'Hack 1', 'Concept 2'];
#
#   function unlock(n) {
#     var block = document.getElementById('lesson-' + n);
#     if (block) {
#       block.style.display = 'block';
#       block.style.animation = 'fadeIn 0.6s ease';
#       if (typeof hljs !== 'undefined') {
#         block.querySelectorAll('pre code').forEach(function(el) {
#           hljs.highlightElement(el);
#         });
#       }
#     }
#     var h2s = document.querySelectorAll('h2');
#     h2s.forEach(function(h) {
#       const label = labels[n-1];
#       if (h.textContent.includes(label)) {
#         h.textContent = h.textContent.replace('\uD83D\uDD12', '\u2705');
#       }
#     });
#     updateSquare(n, labels[n-1]);
#     var progress = document.getElementById('lesson-progress');
#     if (progress) {
#       if (n < 3) {
#         progress.innerHTML = '\u2705 ' + labels[n-1] + ' unlocked! Destroy ' + milestones[n] + ' total enemies for the next one.';
#       } else {
#         progress.innerHTML = '\uD83C\uDF89 <strong>All sections unlocked!</strong> You finished the Backgrounds lesson.';
#       }
#     }
#   }
#
#   window.addEventListener('vs-kills', function(e) {
#     var total = e.detail && e.detail.total;
#     if (!total) return;
#     var counter = document.getElementById('kill-counter');
#     if (counter) counter.textContent = total + ' kill' + (total === 1 ? '' : 's');
#     milestones.forEach(function(m, idx) {
#       if (total >= m && unlocked <= idx) {
#         unlocked = idx + 1;
#         unlock(idx + 1);
#       }
#     });
#   });
#
#   var style = document.createElement('style');
#   style.textContent = '@keyframes fadeIn { from { opacity: 0; transform: translateY(10px); } to { opacity: 1; transform: translateY(0); } }';
#   document.head.appendChild(style);
# })();
# </script>
